# %% [markdown]
# # Atlantic Technological University
# ![image.png](attachment:image.png)

# %% [markdown]
# # Higher Diploma in Science in Computing (Data Analytics)-Level 8

# %% [markdown]
# # Data Representation 23_24 Final Project

# %% [markdown]
# ### Author: Jean-Samuel Bonsenge-Bokanga

# %% [markdown]
# ![image.png](attachment:image.png)
# https://asiapacific.unwomen.org/en/digital-library/publications/2022/06/two-years-onhttps://asiapacific.unwomen.org/en/digital-library/publications/2022/06/two-years-on#view

# %% [markdown]
# ### Geographic coverage
# #### Asia and the Pacific:
# Indonesia, Kiribati, Pakistan, Papua New Guinea, Samoa, Solomon Islands, and Tonga.

# %% [markdown]
# ### Import relevant modules from Python Package and access the dataset

# %%
# Data frame and structuration.
import pandas as pd

# %%
# Secure Sockets Layer(SSL)certification.
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Access and read the dataset.
df = pd.read_csv("https://data.unwomen.org/sites/default/files/documents/Publications/Asia%20Pacific/RGAs%20Asia%20and%20Pacific-CSV.csv")
# Out:
# C:\Users\Neringa\anaconda31\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Display the dataset. df.head() and df.tail() functions are automatically performed as displayed below.
df
# Out:
#          country        id       date     s1a     a01 a02 a02agegroup_type1  \
# 0      Indonesia  IN100032   8-Oct-21  Bahasa    Male  43             40-49
# 1      Indonesia  IN100093   8-Oct-21  Bahasa  Female  47             40-49
# 2      Indonesia  IN100096   8-Oct-21  Bahasa    Male  28             18-29
# 3      Indonesia  IN100099  13-Oct-21  Bahasa    Male  38             30-39
# 4      Indonesia   IN10011   8-Oct-21  Bahasa  Female  52             50-59
# ...          ...       ...        ...     ...     ...  ..               ...
# 17840      Tonga      9708  13-Oct-21  Tongan  Female  75               60+
# 17841      Tonga      9729  13-Oct-21  Tongan  Female  40             40-49
# 17842      Tonga      9775  13-Oct-21  Tongan  Female  78               60+
# 17843      Tonga      9810  13-Oct-21  Tongan    Male  26             18-29
# 17844      Tonga      9825  13-Oct-21  Tongan  Female  31             30-39
#
#       a02agegroup_type2                 a03          a03urbrur  ...  \
# 0                 40-50                Town  Urban (city+town)  ...
# 1                 40-50                Town  Urban (city+town)  ...
# 2                 18-28                Town  Urban (city+town)  ...
# 3                 29-39                City  Urban (city+town)  ...
# 4                 51-61                City  Urban (city+town)  ...
# ...                 ...                 ...                ...  ...
# 17840               62+  Village/rural area              Rural  ...
# 17841             40-50                Town  Urban (city+town)  ...
# 17842               62+  Village/rural area              Rural  ...
# 17843             18-28  Village/rural area              Rural  ...
# 17844             29-39  Village/rural area              Rural  ...
#
#            e01a6                                             e01a7  \
# 0              .                                                 .
# 1              .                                                 .
# 2              .                                                 .
# 3              .                                         Unchanged
# 4              .  Initially changed but has now returned to normal
# ...          ...                                               ...
# 17840  Unchanged                                         Unchanged
# 17841  Unchanged                                         Unchanged
# 17842  Increased                                                 .
# 17843  Unchanged                                         Unchanged
# 17844  Unchanged                                         Unchanged
#
#                                                   e01a8                 e01a9  \
# 0                                             Unchanged                     .
# 1                                  Do not usually do it  Do not usually do it
# 2                                                     .                     .
# 3                                             Unchanged             Unchanged
# 4      Initially changed but has now returned to normal             Decreased
# ...                                                 ...                   ...
# 17840                                         Unchanged             Unchanged
# 17841                                         Unchanged             Unchanged
# 17842                                                 .                     .
# 17843                                         Unchanged             Unchanged
# 17844                                         Unchanged             Unchanged
#
#                                                  e01a10  \
# 0                                                     .
# 1      Initially changed but has now returned to normal
# 2                                                     .
# 3                                             Unchanged
# 4      Initially changed but has now returned to normal
# ...                                                 ...
# 17840                                         Unchanged
# 17841                                         Unchanged
# 17842                                                 .
# 17843                                         Unchanged
# 17844                                         Unchanged
#
#                                                  e01a11  \
# 0                                                     .
# 1                                                     .
# 2                                                     .
# 3                                                     .
# 4      Initially changed but has now returned to normal
# ...                                                 ...
# 17840                                         Unchanged
# 17841                                         Unchanged
# 17842                                         Unchanged
# 17843                              Do not usually do it
# 17844                                         Unchanged
#
#                                                  e01a12  \
# 0                                                     .
# 1                                                     .
# 2                                                     .
# 3                                                     .
# 4      Initially changed but has now returned to normal
# ...                                                 ...
# 17840                                         Unchanged
# 17841                                         Unchanged
# 17842                                         Unchanged
# 17843                              Do not usually do it
# 17844                                                 .
#
#                                                  e01a13  f01      ww
# 0                                             Unchanged   No  0.7256
# 1                                                     .  Yes  1.9451
# 2                                             Unchanged   No  0.8936
# 3                                                     .   No  0.8321
# 4      Initially changed but has now returned to normal  Yes  0.3841
# ...                                                 ...  ...     ...
# 17840                                         Unchanged   No  1.9319
# 17841                              Do not usually do it   No  0.4813
# 17842                                         Unchanged  Yes  2.0965
# 17843                                         Unchanged   No  1.8189
# 17844                                         Unchanged   No  1.7071
#
# [17845 rows x 103 columns]

# %%
# Have a look at statistics summary.
df.describe()
# Out:
#               a07a1         a07a2         a07a3          a07b
# count  17845.000000  17845.000000  17845.000000  17845.000000
# mean       2.351975      3.803867      0.360773      6.516559
# std        2.064232      2.357239      0.714414      3.656134
# min        0.000000      0.000000      0.000000      1.000000
# 25%        1.000000      2.000000      0.000000      4.000000
# 50%        2.000000      3.000000      0.000000      6.000000
# 75%        3.000000      5.000000      1.000000      8.000000
# max       27.000000     50.000000     20.000000     50.000000

# %% [markdown]
# ### To display the remaining country entries samples use df.iloc() functions as below.

# %%
# Kiribati. Execute the df.iloc() to have the other four entries using the index 4251 until 4254.
df.iloc[[4250]]
# Out:
#        country    id      date         s1a   a01 a02 a02agegroup_type1  \
# 4250  Kiribati  6850  9-Oct-21  Gilbertise  Male  36             30-39
#
#      a02agegroup_type2   a03          a03urbrur  ...      e01a6      e01a7  \
# 4250             29-39  City  Urban (city+town)  ...  Unchanged  Unchanged
#
#           e01a8      e01a9     e01a10     e01a11     e01a12     e01a13  f01  \
# 4250  Unchanged  Unchanged  Unchanged  Unchanged  Unchanged  Unchanged  Yes
#
#           ww
# 4250  0.7129
#
# [1 rows x 103 columns]

# %%
# Pakistan. Execute the df.iloc() to have the other four entries using the index 5551 until 5554.
df.iloc[[5550]]
# Out:
#        country     id       date   s1a     a01 a02 a02agegroup_type1  \
# 5550  Pakistan  P3509  30-Oct-21  Urdu  Female  55             50-59
#
#      a02agegroup_type2   a03          a03urbrur  ...      e01a6 e01a7 e01a8  \
# 5550             51-61  City  Urban (city+town)  ...  Decreased     .     .
#
#      e01a9  e01a10  e01a11  e01a12  e01a13  f01      ww
# 5550     .       .       .       .       .  Yes  0.8316
#
# [1 rows x 103 columns]

# %%
# Papua New Guinea. Execute the df.iloc() to have the other four entries using the index 8371 until 8374.
df.iloc[[8370]]
# Out:
#      country     id       date        s1a     a01 a02 a02agegroup_type1  \
# 8370     PNG  13137  18-Oct-21  Tok Pisin  Female  21             18-29
#
#      a02agegroup_type2   a03          a03urbrur  ...      e01a6      e01a7  \
# 8370             18-28  Town  Urban (city+town)  ...  Decreased  Decreased
#
#           e01a8      e01a9     e01a10     e01a11     e01a12     e01a13 f01  \
# 8370  Decreased  Decreased  Decreased  Decreased  Decreased  Decreased  No
#
#           ww
# 8370  0.1937
#
# [1 rows x 103 columns]

# %%
# Samoa. Execute the df.iloc() to have the other four entries using the index 11991 until 11994.
df.iloc[[11990]]
# Out:
#       country     id       date     s1a   a01 a02 a02agegroup_type1  \
# 11990   Samoa  24828  29-Oct-21  Samoan  Male  53             50-59
#
#       a02agegroup_type2                 a03 a03urbrur  ...      e01a6  \
# 11990             51-61  Village/rural area     Rural  ...  Unchanged
#
#            e01a7      e01a8      e01a9     e01a10     e01a11     e01a12  \
# 11990  Unchanged  Unchanged  Unchanged  Unchanged  Unchanged  Unchanged
#
#           e01a13 f01      ww
# 11990  Unchanged  No  2.1026
#
# [1 rows x 103 columns]

# %%
# Solomon Islands. Execute the df.iloc() to have the other four entries using the index 11990, 11993 until 11995.
df.iloc[[13990]]
# Out:
#               country     id       date         s1a   a01 a02  \
# 13990  Solomon Island  21851  27-Oct-21  Sols Pijin  Male  70
#
#       a02agegroup_type1 a02agegroup_type2   a03          a03urbrur  ...  \
# 13990               60+               62+  Town  Urban (city+town)  ...
#
#            e01a6 e01a7 e01a8      e01a9     e01a10     e01a11     e01a12  \
# 13990  Unchanged     .     .  Unchanged  Unchanged  Unchanged  Unchanged
#
#        e01a13  f01      ww
# 13990       .  Yes  0.4132
#
# [1 rows x 103 columns]

# %% [markdown]
# ### CRUD Operations, Dataset structure and output in JSON format

# %%
# import the Flask class.
from flask import Flask, url_for, request, redirect, abort, jsonify
# create an instance of the above class.
app = Flask(__name__, static_url_path='', static_folder='staticpages')
# use the root() decorator.
@app.route('/')
# create a function.
def index():
    # return an HTML content-type.
    # http://127.0.0.1:5000  or curl http://127.0.0.1:5000
    return "UN Women Gender and Covid-19 Survey Report 2022."

# Step 1 Get All using the getAll()function.
# curl http://127.0.0.1:5000/GCdata.
# GCdata means gender data.
@ app.route('/GCdata')
def get_All():
    return "served by Get_All()"

# curl http://127.0.0.1:5000/GCdata/1
@ app.route('/GCdata/<int:id>')
def findBy(id):
    return"served by findBy id with it "+str(id)

# Step 2 Create using the POST() method.
# curl -X POST http://127.0.0.1:5000/GCdata/2
@ app.route('/GCdata', methods = ["POST"])
def create():
    return "served by Create"
# Step 3 Update using the PUT()attribute.
# curl -X PUT http://127.0.0.1:5000/GCdata/3
@ app.route('/GCdata/<int:id>', methods = ["PUT"])
def update(id):
    return "served by update with it" + str(id)

# Step 4 Delete or remove using the DELETE() method.
# curl - X DELETE  http://127.0.0.1:5000/GCdata/4
@ app.route('/GCdata/<int:id>', methods = ["DELETE"])
def delete(id):
    return "served by delete with it" + str(id)

# Write code for each of CRUD operations.
# Make an array of data from UN Women database.
GCdataset=[{"id":0, "Country":"Indonesia","Sexe":"Male", "Age": 43},    
{"id":1, "Country":"Indonesia","Sexe":"Female", "Age": 47},                      
{"id":4350, "Country":"Kiribati", "Sexe": "Female", "Age": 35},
{"id":4351, "Country":"Kiribati", "Sexe": "Female", "Age": 19},                            
{"id":5550, "Country":"Pakistan", "Sexe": "Female", "Age": 55},
{"id":5551, "Country":"Pakistan", "Sexe": "Male", "Age":23},                    
{"id":8370, "Country":"PNG(Papua New Guinea)","Sexe":"Female", "Age":21},
{"id":8371, "Country":"PNG(Papua New Guinea)","Sexe":"Male", "Age": 34},          
{"id":11990, "Country":"Samoa","Sexe":"Male", "Age":53},
{"id":11991, "Country":"Samoa","Sexe":"Male", "Age": 32},                    
{"id":13993, "Country":"Solomon Island", "Sexe": "Male", "Age":32},
{"id":13994, "Country":"Solomon Island", "Sexe": "Female", "Age":26},          
{"id":17840, "Country":"Tonga", "Sexe": "Female", "Age": 75},          
{"id":17841, "Country":"Tonga", "Sexe": "Female", "Age": 40}]

# number of CRUD operations.
nextId=4
# getAll.
# curl http://127.0.0.1:5000/GCdataset
@ app.route('/GCdataset')
def getAll():
    return jsonify(GCdataset)

# find by id.
# curl http://127.0.0.1:5000/GCdataset/1

@ app.route('/GCdataset/<int:id>')
def find_By(id):
    foundData=list(filter(lambda t:t["id"] == id, GCdataset))
    if len (foundData) == 0:
        return jsonify ({}, 204)
    return jsonify(foundData[0])
     
# create
# curl -X POST -H "Content-type:application/json" -d "{\"Country\": \"Papua New Guinea\", \"Sexe\": \"Male\", \"Age\":40}" http://127.0.0.1:5000/GCdataset/2
@ app.route('/GCdataset',methods=["POST"])
def CreateD():
    global nextId
    if not request.json:
        abort(400)
    dataset={
        "id":nextId,
        "Country":request.json["Country"],
        "Sexe":request.json["Sexe"],
        "Age":request.json["Age"]
        }
    GCdataset.append(dataset)
    nextId+=1
    return jsonify(dataset)

#update
# curl -X PUT -H "Content-type:application/json" -d "{\"Country\": \"Papua New Guinea\", \"Sexe\": \"Male\", \"Age\":40}" http://127.0.0.1:5000/GCdataset/3
@app.route('/GCdataset/<int:id>',methods=['PUT'])
def up_date(id):
    foundData=list(filter(lambda t: t["id"] == id, GCdataset))
    if len(foundData) == 0:
        return jsonify({}), 404
    currentdataset=foundData[0]
    if 'Country' in request.json:
        currentdataset['Country']=request.json['Country']
    if 'Age' in request.json:
        currentdataset['Age']=request.json['Age']
    if 'Sexe' in request.json:
        currentdataset['Sexe']=request.json['Sexe']
    return jsonify(currentdataset)

# delete
# curl -X DELETE http://127.0.0.1:5000/GCdataset/4
@ app.route('/GCdataset/<int:id>',methods= ["DELETE"])
def Delete(id):
    foundData=list(filter(lambda t:t["id"]==id, GCdataset))
    if len (foundData)==0:
        return jsonify ({}), 404
    GCdataset.remove(foundData[0])
    return jsonify ({"done":True})

if __name__ == "__main__":
    app.run(debug= False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Dec/2023 16:49:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Dec/2023 16:49:09] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Dec/2023 16:49:19] "GET /GCdataset HTTP/1.1" 200 -

# %% [markdown]
# ### Output after running the above code as Running on http://127.0.0.1:5000/GCdataset

# %%
[
    {
        "Age": 43,
        "Country": "Indonesia",
        "Sexe": "Male",
        "id": 0
    },
    {
        "Age": 47,
        "Country": "Indonesia",
        "Sexe": "Female",
        "id": 1
    },
    {
        "Age": 35,
        "Country": "Kiribati",
        "Sexe": "Female",
        "id": 4350
    },
    {
        "Age": 19,
        "Country": "Kiribati",
        "Sexe": "Female",
        "id": 4351
    },
    {
        "Age": 55,
        "Country": "Pakistan",
        "Sexe": "Female",
        "id": 5550
    },
    {
        "Age": 23,
        "Country": "Pakistan",
        "Sexe": "Male",
        "id": 5551
    },
    {
        "Age": 21,
        "Country": "PNG(Papua New Guinea)",
        "Sexe": "Female",
        "id": 8370
    },
    {
        "Age": 34,
        "Country": "PNG(Papua New Guinea)",
        "Sexe": "Male",
        "id": 8371
    },
    {
        "Age": 53,
        "Country": "Samoa",
        "Sexe": "Male",
        "id": 11990
    },
    {
        "Age": 32,
        "Country": "Samoa",
        "Sexe": "Male",
        "id": 11991
    },
    {
        "Age": 32,
        "Country": "Solomon Island",
        "Sexe": "Male",
        "id": 13993
    },
    {
        "Age": 26,
        "Country": "Solomon Island",
        "Sexe": "Female",
        "id": 13994
    },
    {
        "Age": 75,
        "Country": "Tonga",
        "Sexe": "Female",
        "id": 17840
    },
    {
        "Age": 40,
        "Country": "Tonga",
        "Sexe": "Female",
        "id": 17841
    }
]

# %% [markdown]
# # End
